# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from numpy import linalg as la

# %%
foto = Image.open('firenze.png')
foto_BN = foto.convert('L') #Luminance
plt.figure(figsize=(4,5))
plt.imshow(foto_BN, cmap='gray')

# %%
foto_mat = np.asarray(foto_BN)
print(foto_mat.shape)
plt.figure(figsize=(10,13))
plt.imshow(foto_mat, cmap='gray')
# Out:
# (4032, 3024)

# %%
la.matrix_rank(foto_mat)
# Out:
# 3024

# %%
[Umat,Smat,Vmat] = la.svd(foto_mat, full_matrices=False)

# %%
Umat
# Out:
# array([[-0.01954581, -0.01058027, -0.01362399, ...,  0.0356456 ,
#         -0.00018856,  0.0042414 ],
#        [-0.01954648, -0.01058257, -0.01363768, ...,  0.01971437,
#         -0.03746792,  0.0240156 ],
#        [-0.01955017, -0.01057629, -0.01362649, ...,  0.03996096,
#          0.00327114,  0.01726159],
#        ...,
#        [-0.00975495, -0.0042498 , -0.00452334, ...,  0.01629726,
#         -0.02920934, -0.0033801 ],
#        [-0.00974537, -0.00426042, -0.00463872, ..., -0.00209876,
#          0.03406259, -0.03597464],
#        [-0.00974268, -0.00421968, -0.00470711, ..., -0.00859507,
#          0.01613686,  0.01287027]])

# %%
def aprox_svd(k,u,s,v):
    return s[0:k]*u[:,0:k]@v[0:k,:]

# %%
foto_mat_10 = aprox_svd(10,Umat,Smat,Vmat)
print(foto_mat_10.shape)
plt.figure(figsize=(10,13))
plt.imshow(foto_mat_10, cmap='gray')
# Out:
# (4032, 3024)

# %%
foto_mat_100 = aprox_svd(100,Umat,Smat,Vmat)
print(foto_mat_100.shape)
plt.figure(figsize=(10,13))
plt.title('k=100')
plt.imshow(foto_mat_100, cmap='gray')
# Out:
# (4032, 3024)

# %%
(4032*300+300+300*3024)/(4032*3024)
# Out:
# 0.17363571586041823
